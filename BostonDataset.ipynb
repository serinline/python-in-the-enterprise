# %%
import pandas 
import numpy 
import pprint 
import matplotlib.pyplot as plot
import sklearn.datasets as sd
import sklearn.linear_model as sl

src = load_boston()
data = src.data
cols = src.feature_names

df = pd.DataFrame(data=data, columns=cols)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df.hist(column="CRIM")
df.hist(column="AGE")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F55C58A340>]],
#       dtype=object)

# %%
values = {}
for i in df.columns:
    col = df[i].values.reshape(-1, 1)
    val = reg.score(col, target)
    values[i]=val
    

    plot.scatter(col, target)
    reg = LinearRegression().fit(col, target)
    prd = reg.predict(col)
    plot.scatter(col, prd)
    plot.title("{0} -> {1}".format(i, val))
    plot.figure()
    

for i in values:
    print(str(i) + ": " + str(values[i]))
# Out:
# CRIM: -0.9731027184062391
# ZN: -1.9901588504668861
# INDUS: -0.11382850789685417
# CHAS: -0.6167968141937694
# NOX: -0.18718925791941143
# RM: -457.6876646720394
# AGE: -4604.9407557083505
# DIS: -0.7689323105174721
# RAD: -2.3242673122810635
# TAX: -353.58339645884934
# PTRATIO: -1.1704364054661736
# B: -6778.3476366467
# LSTAT: -1.621232313491698
